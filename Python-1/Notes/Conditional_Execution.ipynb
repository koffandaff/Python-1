# %% [markdown]
# # Chapter 2: **Condition Execution and Iteration**
#
# 1. If
# 2. If-else
# 3. if-elif-else
# 4. nested if
# 5. while
# 6. for
# 7. nested loop
# 8. Break
# 9. Continue
#
# ---

# %% [markdown]
# ## 1. if

# %%
if 1==1: print("Yo")
# Out:
# Yo

# %% [markdown]
# ---
#
# ## 2. If-else

# %%
name = input("Enter Your Name: ")

if name == "Vraj":
    print("Sybau")
else:
    print("You are good to go")
# Out:
# Enter Your Name: Vraj
# Sybau

# %% [markdown]
# ---
#
# ## 3. if-elif-else

# %%
name= input("Enter Your Name: ")
age = int(input("Enter Your age: "))

if age<=12:
    print("Kid Get the fuck out")
elif name == "Vraj":
    print("Nice try diddy, Sybau")
elif 12 < age < 18:
    print("Wellcome to the teen lad.")
elif 18 <= age < 50:
    print("Get a job")
elif age>=50:
    print("Aren't You too old for this ")
else: 
    print("Enter a valid age")
# Out:
# Enter Your Name: Vraj
# Enter Your age: 19
# Nice try diddy, Sybau

# %% [markdown]
# ---
#
# ## 4. Nested-if

# %%
name = input("Enter Your name: ")
age = int(input("Enter Your age: "))

if age>18:
    if name == "Vraj":
        print("Nice Try Diddy")
    elif name == "Dhruvil":
        print("This was all part of my plan lil bro")
    else: 
        print("Get a job")
else:
    print("Get off this shit minor")
# Out:
# Enter Your name: Vraj
# Enter Your age: 19
# Nice Try Diddy
