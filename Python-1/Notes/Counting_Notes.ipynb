# %% [markdown]
# # WAP to calculate the number of notes[500, 200, 100, 50, 20 , 10,] if we will give user input values
#
# ---

# %%
billor = int(input("Enter the amount of cash:"))

bill = billor 

count5 = bill//500 # count the Number of 500 notes we are gonna use

bill %= 500 # Now the remainig amount where we cannot use 500 note

count2 = bill//200 # Checking if we can use 200 

bill %= 200 # Now the reaming amount 

count1 = bill//100 # so on 

bill %= 100 # so on

count50 = bill//50 # so on 

bill %= 50 # so on

count20 = bill//20 # so on

bill %= 20 # so on

count10 = bill//10 # so on

bill %=10 # so on 

count5r = bill//5 # so on 

bill %= 5 # so on 

count2r = bill//2 # so on 

bill %= 2 # so on 

count1r = bill//1 # so on 

bill %= 1 # here bill should be 0 

print(f"The Notes used for the amount: {billor} \n")
print("-------------------------------------------")
print(f" 500 notes: {count5} \n 200 notes: {count2} \n 100 notes: {count1} \n 50 notes: {count50} \n 20 notes: {count20} \n 10 notes: {count10} \n 5 ruppee: {count5r} \n 2 ruppee: {count2r} \n 1 ruppee: {count1r} \n ---------------------------------------------- \n  ")
print("Thanks for Shopping ")
# Out:
# Enter the amount of cash:888
# The Notes used for the amount: 888
#
# -------------------------------------------
#  500 notes: 1
#  200 notes: 1
#  100 notes: 1
#  50 notes: 1
#  20 notes: 1
#  10 notes: 1
#  5 ruppee: 1
#  2 ruppee: 1
#  1 ruppee: 1
#  ----------------------------------------------
#
# Thanks for Shopping
