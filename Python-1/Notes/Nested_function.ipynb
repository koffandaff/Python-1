# %% [markdown]
# # Nested Function

# %% [markdown]
# ### case 1

# %%
def fun1():
    print("YOHOHO")
    
    def fun2():
        print("ZURURURU")
    fun2() # this is the only way to access fun2 i.e inside fun1
        
fun1() # will only go to fun1 not  fun2
# Out:
# YOHOHO
# ZURURURU
