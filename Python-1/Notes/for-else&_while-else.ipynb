# %% [markdown]
# # For-else & While-else [ useless peice of shit]

# %%
# simple representation of what it means
for i in range(5):
    print(i)
else:
    print("Moj ma")

# same for while
# Out:
# 0
# 1
# 2
# 3
# 4
# Moj ma

# %% [markdown]
# ## The only case when the else won't be excuted is that we break the loop

# %%
for i in range(5):
    print(i)
    if i==3:
        break # once it breaks the else block won't be executed
else:
    print("Moj ma")
    
# same for the fucking while loop
# Out:
# 0
# 1
# 2
# 3
